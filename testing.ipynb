# %%
import xarray as xr
from glob import glob
import os
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import numpy as np

# %%
allfiles = glob('/home/axb170054/scratch/from_cheyenne/postprocessed-testing/GITM*.nc')
allfiles = np.sort(allfiles)
ds = xr.open_mfdataset(allfiles[:5]).load()

# %%
ds.VerticalTEC.shape, ds.Rho.shape
# Out:
# ((5, 94, 184), (5, 94, 184, 54))

# %%
ds.VerticalTEC
# Out:
# <xarray.DataArray 'VerticalTEC' (time: 5, lon: 94, lat: 184)>
# array([[[        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,  9.72236832, ..., 13.84519237,
#                  nan,         nan],
#         ...,
#         [        nan,         nan,  9.7072705 , ..., 13.84254454,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan]],
#
#        [[        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan,         nan, ...,         nan,
#                  nan,         nan],
#         [        nan,         nan, 10.24096086, ..., 16.05919162,
# ...

# %%
# ax = plt.subplot(projection=ccrs.PlateCarree())

p = ds.Rho.sel(alt=450, method='nearest').isel(time=[0,4]).plot(
    transform=ccrs.PlateCarree(),
    subplot_kws={"projection": ccrs.PlateCarree()},
    col='time', x = 'lon',y='lat')

for ax in p.axs.flatten():
    ax.coastlines()

plt.show()
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # ax = plt.subplot(projection=ccrs.PlateCarree())
# ----> 3 p = ds.Rho.sel(alt=450, method='nearest').isel(time=[0,4]).plot(
#       4     transform=ccrs.PlateCarree(),
#       5     subplot_kws={"projection": ccrs.PlateCarree()},
#       6     col='time', x = 'lon',y='lat')
#       8 for ax in p.axs.flatten():
#       9     ax.coastlines()
#
# File ~/.conda/envs/py38/lib/python3.8/site-packages/xarray/plot/plot.py:862, in _PlotMethods.__call__(self, **kwargs)
#     861 def __call__(self, **kwargs):
# --> 862     return plot(self._da, **kwargs)
#
# ...

# %%
p = ds.Rho.sel(alt=450, method='nearest').isel(time=3).plot(
    transform=ccrs.PlateCarree(),
    subplot_kws={"projection": ccrs.PlateCarree()},
    x = 'lon',y='lat')

p.axes.coastlines()

plt.show()
